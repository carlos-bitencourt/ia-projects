# %% [markdown]
# Dataset cocomo81

# %%
from scipy.io import arff
import pandas as pd
data = arff.loadarff('datasets/cocomo81.arff')
df = pd.DataFrame(data[0])
df.head()
# Out:
#    rely  data  cplx  time  stor  virt  turn  acap  aexp  pcap  vexp  lexp  \
# 0  0.88  1.16  0.70   1.0  1.06  1.15  1.07  1.19  1.13  1.17   1.1  1.00
# 1  0.88  1.16  0.85   1.0  1.06  1.00  1.07  1.00  0.91  1.00   0.9  0.95
# 2  1.00  1.16  0.85   1.0  1.00  0.87  0.94  0.86  0.82  0.86   0.9  0.95
# 3  0.75  1.16  0.70   1.0  1.00  0.87  1.00  1.19  0.91  1.42   1.0  0.95
# 4  0.88  0.94  1.00   1.0  1.00  0.87  1.00  1.00  1.00  0.86   0.9  0.95
#
#    modp  tool  sced    loc  actual
# 0  1.24  1.10  1.04  113.0  2040.0
# 1  1.10  1.00  1.00  293.0  1600.0
# 2  0.91  0.91  1.00  132.0   243.0
# 3  1.24  1.00  1.04   60.0   240.0
# 4  1.24  1.00  1.00   16.0    33.0

# %% [markdown]
# Dataset Nasa

# %%
data = arff.loadarff('datasets/nasa_numeric.arff')
df = pd.DataFrame(data[0])
df.head()
# Out:
#    recordnumber projectname                   cat2  forg center    year  \
# 0           1.0       b'de'  b'avionicsmonitoring'  b'g'   b'2'  1979.0
# 1           2.0       b'de'  b'avionicsmonitoring'  b'g'   b'2'  1979.0
# 2           3.0       b'de'  b'avionicsmonitoring'  b'g'   b'2'  1979.0
# 3           4.0       b'de'  b'avionicsmonitoring'  b'g'   b'2'  1979.0
# 4           5.0       b'de'  b'avionicsmonitoring'  b'g'   b'2'  1979.0
#
#               mode  rely  data  cplx  ...  acap  aexp  pcap  vexp  lexp  modp  \
# 0  b'semidetached'  b'h'  b'l'  b'h'  ...  b'n'  b'n'  b'n'  b'n'  b'h'  b'h'
# 1  b'semidetached'  b'h'  b'l'  b'h'  ...  b'n'  b'n'  b'n'  b'n'  b'h'  b'h'
# 2  b'semidetached'  b'h'  b'l'  b'h'  ...  b'n'  b'n'  b'n'  b'n'  b'h'  b'h'
# 3  b'semidetached'  b'h'  b'l'  b'h'  ...  b'n'  b'n'  b'n'  b'n'  b'h'  b'h'
# 4  b'semidetached'  b'h'  b'l'  b'h'  ...  b'n'  b'n'  b'n'  b'n'  b'h'  b'h'
#
#    tool  sced equivphyskloc act_effort
# ...

# %%
Dataset cocomonasa_v1

# %%
data = arff.loadarff('datasets/cocomonasa_v1.arff')
df = pd.DataFrame(data[0])
df.head()
# Out:
#            RELY     DATA          CPLX          TIME          STOR  \
# 0    b'Nominal'  b'High'  b'Very_High'    b'Nominal'    b'Nominal'
# 1  b'Very_High'  b'High'       b'High'  b'Very_High'  b'Very_High'
# 2    b'Nominal'  b'High'       b'High'  b'Very_High'       b'High'
# 3       b'High'   b'Low'       b'High'    b'Nominal'    b'Nominal'
# 4       b'High'   b'Low'       b'High'    b'Nominal'    b'Nominal'
#
#          VIRT        TURN          ACAP          AEXP          PCAP  \
# 0      b'Low'  b'Nominal'       b'High'    b'Nominal'  b'Very_High'
# 1  b'Nominal'  b'Nominal'  b'Very_High'  b'Very_High'  b'Very_High'
# 2      b'Low'     b'High'       b'High'    b'Nominal'       b'High'
# 3      b'Low'      b'Low'    b'Nominal'    b'Nominal'    b'Nominal'
# 4      b'Low'      b'Low'    b'Nominal'    b'Nominal'    b'Nominal'
#
#          VEXP        LEXP     MODP        TOOL    SCED    LOC  ACT_EFFORT
# 0      b'Low'  b'Nominal'  b'High'  b'Nominal'  b'Low'   70.0       278.0
# ...

# %% [markdown]
# Dataset desharnais

# %%
data = arff.loadarff('datasets/desharnais.arff')
df = pd.DataFrame(data[0])
df.head()
# Out:
#    Project  TeamExp  ManagerExp  YearEnd  Length  Effort  Transactions  \
# 0      1.0      1.0         4.0     85.0    12.0  5152.0         253.0
# 1      2.0      0.0         0.0     86.0     4.0  5635.0         197.0
# 2      3.0      4.0         4.0     85.0     1.0   805.0          40.0
# 3      4.0      0.0         0.0     86.0     5.0  3829.0         200.0
# 4      5.0      0.0         0.0     86.0     4.0  2149.0         140.0
#
#    Entities  PointsAdjust  Envergure  PointsNonAjust Language
# 0      52.0         305.0       34.0           302.0     b'1'
# 1     124.0         321.0       33.0           315.0     b'1'
# 2      60.0         100.0       18.0            83.0     b'1'
# 3     119.0         319.0       30.0           303.0     b'1'
# 4      94.0         234.0       24.0           208.0     b'1'

# %% [markdown]
# Dataset SEERA

# %%
data = pd.read_csv('datasets/seera.csv', sep = ';')
data.head()
# Out:
#   General Information       Unnamed: 1       Unnamed: 2         Unnamed: 3  \
# 0              ProjID  Year of project  Organization id  Organization type
# 1                   1             2015                1                  1
# 2                   2             2016               25                  5
# 3                   3             2008                2                  5
# 4                   4             2009               42                  4
#
#              Unnamed: 4            Unnamed: 5             Unnamed: 6  \
# 0  Role in organization  Size of organization  Size of IT department
# 1                     1                    16                      7
# 2                     1                     2                      1
# 3                     3                     2                      2
# 4                     2                     3                      2
#
#                    Unnamed: 7           Unnamed: 8       Unnamed: 9  ...  \
# ...
